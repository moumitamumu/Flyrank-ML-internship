# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/moumitamumu/Flyrank-ML-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# Task Type: Ranking
#
# My chosen lane is Content Ranking for SEO. The goal is to rank webpages according to their expected search performance so that the best-performing content appears first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ### Target or Proxy
#
# **Target:** Search Performance Score
#
# **Proxy:**
# The model predicts a ranking score for each webpage based on historical SEO performance.
#
# Higher score = Better ranking potential.

# %% [markdown]
# ## Target or Proxy
#
# The target is the search performance of a page.
#
# Proxy target:
# - Organic Clicks
#
# Organic clicks are used because they reflect how well a page performs in search results.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success Metric:
# NDCG (Normalized Discounted Cumulative Gain)
#
# Reason:
# NDCG measures how well the predicted ranking matches the ideal ranking of webpages.

# %% [markdown]
# ## Success Metric
#
# Primary Metric:
# - NDCG
#
# Secondary Metrics:
# - Precision@10
# - Mean Average Precision (MAP)
#
# These metrics evaluate how well the ranking places the best content at the top.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

df.head()
df.info()
df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  str
#  1   client_id               30000 non-null  str
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  str
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  str
#  7   main_intent             27626 non-null  str
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   str
#  11  model_used              24267 non-null  str
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %% [markdown]
# df.head()
# df.info()
# df.shape
# ## Unit of Analysis
#
# One row represents one content page.
#
# Each row contains information such as URL, title, impressions, clicks, CTR, and other features used for ranking.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML beats a fixed rule
#
# A fixed rule cannot effectively combine many signals such as impressions, CTR, keyword relevance, page quality, freshness, and engagement.
#
# Machine learning learns patterns from historical data and produces better rankings than manually written rules.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ✅ Task type identified.
#
# ✅ Target defined.
#
# ✅ Success metric selected.
#
# ✅ Dataframe loaded.
#
# ✅ Unit of analysis explained.
#
# ✅ Reason for using ML explained.
